# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self, value=None):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1

    def __str__(self):
        if self.length == 0:
            return "None"
        if self.tail is None:
            return "None"
        temp = self.head
        string = ""
        while temp:
            if temp.next is None:
                string += str(temp.value)
            else:
                string += str(temp.value) + " => "
            temp = temp.next
        return string

    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def pop(self):
        if self.head is None:
            return None
        pre = self.head
        temp = self.head
        while temp.next is not None:
            pre = temp
            temp = temp.next
        self.tail = pre
        self.tail.next = None
        self.length -= 1
        temp = None
        if self.length == 0:
            self.head = None
            self.tail = None

    def prepend(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            temp = self.head
            self.head = new_node
            self.head.next = temp
        self.length += 1

    def pop_first(self):
        if self.head is None:
            return None
        temp = self.head
        self.head = self.head.next
        self.length -= 1

    def get(self, index):
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        return temp.value

    def set_value(self, index, value):
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        temp.value = value

    def remove(self, index):
        if index < 0 or index >= self.length:
            return None
        if index == 0:
            return self.pop_first()
        if index == self.length - 1:
            return self.pop()
        pre = self.head
        temp = self.head
        nexty = self.head
        for _ in range(index):
            pre = temp
            temp = temp.next
        pre.next = temp.next
        self.length -= 1

    def insert(self, index, value):
        new_node = Node(value)
        if index < 0 or index >= self.length:
            return None
        if index == 0:
            temp = self.head
            self.head = new_node
            self.head.next = temp
            self.length += 1
        else:
            pre = self.head
            temp = self.head
            for _ in range(index):
                pre = temp
                temp = temp.next
            print(pre.value, temp.value)
            pre.next = new_node
            new_node.next = temp
            self.length += 1

    def reverse(self):
        pre = None
        curr = self.head
        while curr:
            #NCPC
            next = curr.next
            curr.next = pre
            pre = curr
            curr = next
        self.head = pre
            
        
        
    
        
l1 = LinkedList(10)
l1.append(20)
l1.append(30)
l1.append(40)
l1.append(50)
# l1.prepend(5)
# l1.pop_first()
# # print(l1.get(1))
# l1.set_value(1,15)
# l1.remove(1)
# l1.append(50)
# l1.set_value(0,15)
# l1.set_value(2, 45)
# l1.insert(1, 25)
# l1.reverse()


print(l1)
# Out:
# 10 => 20 => 30 => 40 => 50

# %%
#https://leetcode.com/problems/middle-of-the-linked-list/description/ - easy

head = l1.head
def middlenode(head):
    slow = head
    fast = head
    while slow and fast.next:
        slow = slow.next
        fast = fast.next.next
    return slow.value
        
print(middlenode(head))
# Out:
# 30

# %%
#https://leetcode.com/problems/remove-nth-node-from-end-of-list/ - medium

print(l1)
head = l1.head

def removeNthFromEnd(head, n):
    temp = head
    length = 1
    
    while temp.next is not None:
        length += 1
        temp = temp.next
        
    index_to_remove = length - n
    
    if length == n:
        head = head.next
    else:
        pre = head
        temp = head
        for _ in range(index_to_remove):
            pre = temp
            temp = temp.next
        pre.next = temp.next
        
    return head.value
    
    
print(removeNthFromEnd(head, 5))
print(l1)
# Out:
# 10 => 20 => 30 => 40 => 50
# 20
# 10 => 20 => 30 => 40 => 50

# %%
# https://leetcode.com/problems/linked-list-cycle/ - easy

print(l1)

head = l1.head

def make_cycle(head, index):
    temp = head
    
    # get the last node
    while temp.next is not None:
        temp = temp.next
    tail = temp
    
    # get the index node
    tempo = head
    for _ in range(index):
        tempo = tempo.next
    
    # now make the last node to point to the index to make a cycle
    temp.next = tail
    
    
# def hasCycle(head):
    

make_cycle(head, 2)
print(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # https://leetcode.com/problems/linked-list-cycle/ - easy
# ----> 3 print(l1)
#       5 head = l1.head
#       7 def make_cycle(head, index):
#
# NameError: name 'l1' is not defined
