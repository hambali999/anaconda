# %%
# Merge Two Sorted Linked List

# You are given the heads of two sorted linked lists list1 and list2. 
# Merge the two lists in a one sorted list. The list should be made by splicing together the nodes of the first two lists.
# Return the head of the merged linked list.   

# Example 1: 
# Input: list1 = [1,2,4], list2 = [1,3,4]
# Output: [1,1,2,3,4,4]

# Example 2:
# Input: list1 = [], list2 = []
# Output: []

# Example 3: 
# Input: list1 = [], list2 = [0]
# Output: [0]


# Constraints: 
# The number of nodes in both lists is in the range [0, 50].
# -100 <= Node.val <= 100
# Both list1 and list2 are sorted in non-decreasing order.

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution(object):
    def mergeTwoLists(self, l1, l2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        if l1 == [] and l2 == []:
            return []


list1 = [1,2,4]
list2 = [1,3,4]

# %%
class Node:
    def __init__(self, value=0, next=None):
        self.value = value
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def __str__(self):
        strl = ""
        temp = self.head
        while temp is not None:
            if temp.next is None:
                strl += str(temp.value)
            else:
                strl += str(temp.value) 
                strl  += " -> "
            temp = temp.next
        return strl

def mergeTwoLists(l1, l2):
    """
    :type list1: Optional[ListNode]
    :type list2: Optional[ListNode]
    :rtype: Optional[ListNode]
    """
    dummy = cur = Node(0)
    print(l1.head.value, l2.head.value)
    l1 = l1.head
    l2 = l2.head
    while l1 and l2:
        if l1.value < l2.value:
            cur.next = l1
            l1 = l1.next
        else:
            cur.next = l2
            l2 = l2.next
        cur = cur.next
    cur.next = l1 or l2
    return dummy.next
    
        
l1 = LinkedList()
l2 = LinkedList()
l1.append(10)
l1.append(20)
l1.append(40)
l2.append(10)
l2.append(30)
l2.append(40)
print(l1)
print(l2)
print('-'*20)

merged_linked_list = mergeTwoLists(l1, l2)

print(merged_linked_list)

temp = merged_linked_list
while temp:
    print(temp.value)
    temp = temp.next
# Out:
# 10 -> 20 -> 40
# 10 -> 30 -> 40
# --------------------
# 10 10
# <__main__.Node object at 0x00000252FF8ADB90>
# 10
# 10
# 20
# 30
# 40
# 40
