# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self, value=None):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1

    def __str__(self):
        if self.length == 0:
            return "None"
        if self.tail is None:
            return "None"
        temp = self.head
        string = ""
        while temp:
            if temp.next is None:
                string += str(temp.value)
            else:
                string += str(temp.value) + " => "
            temp = temp.next
        return string

    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def pop(self):
        if self.head is None:
            return None
        pre = self.head
        temp = self.head
        while temp.next is not None:
            pre = temp
            temp = temp.next
        self.tail = pre
        self.tail.next = None
        self.length -= 1
        temp = None
        if self.length == 0:
            self.head = None
            self.tail = None

    def prepend(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            temp = self.head
            self.head = new_node
            self.head.next = temp
        self.length += 1

    def pop_first(self):
        if self.head is None:
            return None
        temp = self.head
        self.head = self.head.next
        self.length -= 1

    def get(self, index):
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        return temp.value

    def set_value(self, index, value):
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        temp.value = value

    def remove(self, index):
        if index < 0 or index >= self.length:
            return None
        if index == 0:
            return self.pop_first()
        if index == self.length - 1:
            return self.pop()
        pre = self.head
        temp = self.head
        nexty = self.head
        for _ in range(index):
            pre = temp
            temp = temp.next
        pre.next = temp.next
        self.length -= 1

    def insert(self, index, value):
        new_node = Node(value)
        if index < 0 or index >= self.length:
            return None
        if index == 0:
            temp = self.head
            self.head = new_node
            self.head.next = temp
            self.length += 1
        else:
            pre = self.head
            temp = self.head
            for _ in range(index):
                pre = temp
                temp = temp.next
            print(pre.value, temp.value)
            pre.next = new_node
            new_node.next = temp
            self.length += 1

    def reverse(self):
        #NCPC
        pre = None
        current = self.head
        while(current):
            next = current.next
            current.next = pre
            pre = current
            current = next
        self.head = pre
            
        
        
    
        
l1 = LinkedList(10)
l1.append(20)
l1.append(30)
# l1.append(40)
# l1.append(50)
# l1.prepend(5)
# l1.pop_first()
# # print(l1.get(1))
# l1.set_value(1,15)
# l1.remove(1)
# l1.append(50)
# l1.set_value(0,15)
# l1.set_value(2, 45)
# l1.insert(1, 25)
# l1.reverse()


print(l1)
# Out:
# 10 => 20 => 30

# %%
#https://leetcode.com/problems/middle-of-the-linked-list/description/ - easy

head = l1.head

def middleNode(head):
    """
    :type head: ListNode
    :rtype: ListNode
    """
    if head is None:
        return None
    slow = head
    fast = head
    if slow.next and fast.next.next is not None:
        slow = slow.next
        fast = fast.next.next
    return slow.value

print(middleNode(head))
# Out:
# 20

# %%
#https://leetcode.com/problems/remove-nth-node-from-end-of-list/ - medium

head = l1.head
print(l1)

def removeNthFromEnd(head, n):
    """
    :type head: ListNode
    :type n: int
    :rtype: ListNode
    """
    length = 0
    temp = head

    # calculate length, then find index through (length - n)
    while temp:
        length += 1
        temp = temp.next

    index = length - n

    # edge cases when index to delete same as length, which means delete the first node\
    print(n, length)
    if n == length:
        head = head.next
    else:
        # loop through, find the index to be removed, and remove it
        pre = head
        temp = head
        for _ in range(index):
            pre = temp
            temp = temp.next
        pre.next = temp.next

    return head
    


print(removeNthFromEnd(head,2))


# test cases
# input: 1,2,3,4,5
# output: 1,2,3,5

# input: 1,2
# output: 2
# Out:
# 10 => 20
# 2 2
# <__main__.Node object at 0x000002C37A715F10>

# %%
# https://leetcode.com/problems/linked-list-cycle/ - easy

# Input: head = [3,2,0,-4], pos = 1
# Output: true
# Explanation: There is a cycle in the linked list, where the tail connects to the 1st node (0-indexed).

def makeCycle(head, target):
    temp = head
    for _ in range(target):
        temp = temp.next
    targetnode = temp
    temp = head
    while temp.next is not None:
        temp = temp.next
    tail = temp
    tail.next = targetnode

def hasCycle(head):
    """
    :type head: ListNode
    :rtype: bool
    """
    print(head.value)
    temp = head
    s = set()
    while temp is not None:
        if temp in s:
            return True
        s.add(temp)
        temp = temp.next
    return False


l2 = LinkedList(3)
l2.append(2)
l2.append(0)
l2.append(-4)

print(l2)
print('---')

head = l2.head

# makeCycle(head, 1)
    

hasCycle(head)
# Out:
# 3 => 2 => 0 => -4
# ---
# 3
# False

# %%
# https://leetcode.com/problems/merge-two-sorted-lists/ - easy

l3 = LinkedList(10)
l4 = LinkedList(10)
l3.append(20)
l3.append(40)
l4.append(30)
l4.append(40)
l4.append(50)
l4.append(60)

def mergeTwoLists(list1, list2):
    """
    :type list1: Optional[ListNode]
    :type list2: Optional[ListNode]
    :rtype: Optional[ListNode]
    """
    # print(list1)
    # print(list2)
    dummy = cur = Node(0)

    l1 = list1.head
    l2 = list2.head

    if l1 is None:
        return l2
    if l2 is None:
        return l1

    while l1 and l2:
        if l1.value < l2.value:
            cur.next = l1
            l1 = l1.next
        else:
            cur.next = l2
            l2 = l2.next
        cur = cur.next
    cur.next = l1 or l2
    return dummy.next

        
print(l3)
print(l4)

mergedLinkedList = mergeTwoLists(l3, l4)

temp = mergedLinkedList
while temp:
    print(temp.value)
    temp = temp.next
# Out:
# 10 => 20 => 40
# 10 => 30 => 40 => 50 => 60
# 10
# 10
# 20
# 30
# 40
# 40
# 50
# 60

# %%
#https://leetcode.com/problems/remove-duplicates-from-sorted-list/description/ - easy

def deleteDuplicates(head):
    """
    :type head: ListNode
    :rtype: ListNode
    """

    cur = head
    while cur:
        while cur.next and cur.next.value == cur.value:
            cur.next = cur.next.next
        cur = cur.next
    return head

    
l5 = LinkedList(10)
l5.append(20)
l5.append(20)
l5.append(30)
print(l5)
print('---')
result = deleteDuplicates(l5.head)
print(l5)
# Out:
# 10 => 20 => 20 => 30
# ---
# 10 => 20 => 30

# %%
l6 = LinkedList(10)
l6.append(20)
l6.append(30)
l6.append(40)
l6.append(50)

print(l6)

head = l6.head


def returnElementFromNthLast(head, value):
    l = 0
    temp = head
    
    while temp:
        l += 1
        temp = temp.next

    if value < 0 or value > l:
        return None

    target = l - value

    temp = head
    for _ in range(target):
        temp = temp.next
        
    return temp.value
    


ans = returnElementFromNthLast(head, 5)

print(ans)
# Out:
# 10 => 20 => 30 => 40 => 50
# 10
