# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

# %%
class CircularLinkedList:
    def __init__(self, value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.tail.next = new_node
        self.length = 1

    def print_list(self):
        temp = self.head
        counter = 1
        if self.head is None:
            return None
        while(temp is not None):
            print(f"{counter}: Current node value: {temp.value}, Next node value: {temp.next.value}")
            temp = temp.next
            counter += 1
            if temp == self.head:
                break

    def make_empty(self):
        self.head = None
        self.tail = None
        self.length = 0

    def append(self, value):
        new_node = Node(value)
        #print(self.head, self.tail, self.length)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
            self.tail.next = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
            self.tail.next = self.head
        self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
            self.tail.next = new_node
        else:
            temp = self.head
            self.tail.next = new_node
            self.head = new_node
            self.head.next = temp
        self.length += 1

    def pop(self):
        if self.length == 1:
            self.head = None
            self.tail = None
            self.length -= 1
        if self.head is None:
            return None
        if self.tail is None:
            return None
        pre = self.head
        temp = self.head
        while(temp.next is not self.head):
            pre = temp
            temp = temp.next
        #print(pre.value, temp.value)
        self.tail = pre
        pre.next = self.head
        self.length -= 1
        temp = None

    def pop_first(self):
        if self.head is None:
            return None
        temp = self.head.next
        self.tail.next = self.head.next
        self.head = self.head.next
        self.length -= 1
        if self.length == 0:
            self.head = None
            self.tail = None
            self.tail.next = None

    def get(self, index):
        if index < 0 or index > self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        #print(temp.value)
        return temp

    def set_value(self, index, value):
        set_node = self.get(index)
        set_node.value = value

    def remove(self, index):
        if index < 0 or index >= self.length:
            return None
        if index == 0:
            return self.pop_first()
        if index == self.length-1:
            return self.pop()
        pre = self.head
        temp = self.head
        for _ in range(index):
            pre = temp
            temp = temp.next
        #print(pre.value, temp.value)
        next = temp.next
        pre.next = next
        self.length -= 1

    def insert(self, index, value):
        new_node = Node(value)
        if index < 0 or index >= self.length:
            return None
        if index == 0: 
            return self.prepend(value)
        if index == self.length:
            return self.append(value)
        pre = self.head
        temp = self.head
        for _ in range(index):
            pre = temp
            temp = temp.next
        #print(pre.value, temp.value)
        pre.next = new_node
        new_node.next = temp
        self.length += 1

    def reverse(self):
        pre = None
        current = self.head
        while(current is not None):
            next = current.next
            current.next = pre
            pre = current
            current = next
        self.head = self.tail

# %%
cll = CircularLinkedList(10)
cll.append(20)
cll.append(30)
cll.prepend(5)
cll.print_list()
print('-'*20)
cll.pop()
cll.print_list()
print('-'*20)
cll.pop()
cll.append(15)
cll.append(20)
cll.print_list()
print('-'*20)
cll.pop_first()
cll.print_list()
print('-'*20)
cll.get(1)
cll.set_value(2,30)
cll.append(40)
cll.print_list()
print('-'*20)
cll.remove(2)
cll.remove(1)
cll.print_list()
print('-'*20)
cll.insert(1, 20)
cll.insert(2,30)
cll.print_list()
print('-'*20)
cll.reverse()
cll.print_list()
# Out:
# 1: Current node value: 5, Next node value: 10
# 2: Current node value: 10, Next node value: 20
# 3: Current node value: 20, Next node value: 30
# 4: Current node value: 30, Next node value: 5
# --------------------
# 1: Current node value: 5, Next node value: 10
# 2: Current node value: 10, Next node value: 20
# 3: Current node value: 20, Next node value: 5
# --------------------
# 1: Current node value: 5, Next node value: 10
# 2: Current node value: 10, Next node value: 15
# 3: Current node value: 15, Next node value: 20
# 4: Current node value: 20, Next node value: 5
# --------------------
# 1: Current node value: 10, Next node value: 15
# 2: Current node value: 15, Next node value: 20
# 3: Current node value: 20, Next node value: 10
# --------------------
# 1: Current node value: 10, Next node value: 15
# 2: Current node value: 15, Next node value: 30
# 3: Current node value: 30, Next node value: 40
# 4: Current node value: 40, Next node value: 10
# --------------------
# 1: Current node value: 10, Next node value: 40
# 2: Current node value: 40, Next node value: 10
# --------------------
# 1: Current node value: 10, Next node value: 20
# 2: Current node value: 20, Next node value: 30
# 3: Current node value: 30, Next node value: 40
# 4: Current node value: 40, Next node value: 10
# --------------------
# 1: Current node value: 40, Next node value: 30
# 2: Current node value: 30, Next node value: 20
# 3: Current node value: 20, Next node value: 10
# 4: Current node value: 10, Next node value: 40
